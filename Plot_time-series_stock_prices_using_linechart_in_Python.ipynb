# %%
import yfinance as yf
AAPL_stock = yf.Ticker('AAPL').history(period='3mo',interval='1d')
print(AAPL_stock)
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2022-03-07  163.120341  164.777909  158.806671  159.066299   96418800
# 2022-03-08  158.586995  162.641036  155.571422  157.209015  131148300
# 2022-03-09  161.243093  163.170269  159.176138  162.710938   91454900
# 2022-03-10  159.964973  160.154697  155.751163  158.287445  105342000
# 2022-03-11  158.696826  159.046318  154.273332  154.502991   96970100
# ...                ...         ...         ...         ...        ...
# 2022-05-31  149.070007  150.660004  146.839996  148.839996  103718400
# 2022-06-01  149.899994  151.740005  147.679993  148.710007   74286600
# 2022-06-02  147.830002  151.270004  146.860001  151.210007   72348100
# 2022-06-03  146.899994  147.970001  144.460007  145.380005   88471400
# 2022-06-06  147.029999  148.568893  144.899994  146.139999   70931362
#
#             Dividends  Stock Splits
# Date
# 2022-03-07        0.0             0
# 2022-03-08        0.0             0
# 2022-03-09        0.0             0
# 2022-03-10        0.0             0
# 2022-03-11        0.0             0
# ...               ...           ...
# 2022-05-31        0.0             0
# 2022-06-01        0.0             0
# 2022-06-02        0.0             0
# 2022-06-03        0.0             0
# 2022-06-06        0.0             0
#
# [64 rows x 7 columns]

# %%
import seaborn as sns
sns.lineplot(data=AAPL_stock, x='Date', y="Close")

# %%
import matplotlib.ticker as ticker
ax=sns.lineplot(data=AAPL_stock, x='Date', y="Close")
ax.xaxis.set_major_locator(ticker.MultipleLocator(25))
